# %% [markdown]
# # Mathematische Modelle zur Beschreibung von Daten

# %% [markdown]
# Wir haben letzte Woche einen Datensatz von handgeschriebenen Ziffern eingelesen. Diese waren im csv-Format gespeichert. Wir haben die handgeschriebenen Ziffern visualisiert und eine Reihe an Statistiken auf den Daten berechnet.
#
# In einem anderen Notebook, haben wir uns Wahrscheinlichkeitsverteilungen angeschaut. Wir haben zu den Wahrscheinlichkeitsverteilungen Zufallszahlen generiert und diese zusammen mit den Wahrscheinlichkeitsdichtefunktionen visualisiert.
#
# Anhand eines weiteren Datensatzes (https://datahub.io/core/global-temp#data) wollen wir nun die zwei Welten zusammenbringen und ein neues Datenformat (JSON) kennenlernen. Wir wollen diese Daten einlesen und anhand von mathematischen Modellfunktionen beschreiben. Bei dem Datensatz handelt es sich um die monatlichen Temperaturmittelwerte für die gesammte Erde.

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import scipy, scipy.stats
import matplotlib.pyplot as plt

# %%
f = open("monthly_json.json", "r") # öffnet die Datei
file_content = f.read(500) # liest die ersten 100 Zeichen der Datei

# %%
file_content
# Out:
# '[{"Date": "2016-12-06", "Mean": 0.7895, "Source": "GCAG"},{"Date": "2016-12-06", "Mean": 0.81, "Source": "GISTEMP"},{"Date": "2016-11-06", "Mean": 0.7504, "Source": "GCAG"},{"Date": "2016-11-06", "Mean": 0.93, "Source": "GISTEMP"},{"Date": "2016-10-06", "Mean": 0.7292, "Source": "GCAG"},{"Date": "2016-10-06", "Mean": 0.89, "Source": "GISTEMP"},{"Date": "2016-09-06", "Mean": 0.8767, "Source": "GCAG"},{"Date": "2016-09-06", "Mean": 0.87, "Source": "GISTEMP"},{"Date": "2016-08-06", "Mean": 0.8998, '

# %% [markdown]
# Wie wir sehen, handelt es sich immernoch um eine Textdatei. Diese ist jedoch in einem grundsätzlich anderen Format aufgebaut. Jedoch gibt es auch hier bereits fertige Interpreter in pandas:

# %%
data = pd.read_json("monthly_json.json")

# %%
data.head()
# Out:
#         Date    Mean   Source
# 0 2016-12-06  0.7895     GCAG
# 1 2016-12-06  0.8100  GISTEMP
# 2 2016-11-06  0.7504     GCAG
# 3 2016-11-06  0.9300  GISTEMP
# 4 2016-10-06  0.7292     GCAG

# %% [markdown]
# Zunächst will ich die Daten etwas umformatieren, so dass das Datum zum index des Dataframes wird und die verschiedenen Quellen (Source) als Spalten dargestellt werden. Dazu nutze ich die Pivot-Funktion von pandas:

# %%
pivot_df = data.pivot(index='Date', columns='Source', values='Mean')

# %%
pivot_df.head()
# Out:
# Source        GCAG  GISTEMP
# Date
# 1880-01-06  0.0009    -0.30
# 1880-02-06 -0.1229    -0.21
# 1880-03-06 -0.1357    -0.18
# 1880-04-06 -0.0499    -0.27
# 1880-05-06 -0.0738    -0.14

# %% [markdown]
# Wie ich aus der Beschreibung der Daten weiß, handelt es sich um einen zeitlichen Verlauf der Temperaturmittelwerte. Diesen will ich zunächst einmal visualisieren um ein gefühl dafür zu bekommen.

# %%
pivot_df.plot(figsize=(20, 8),);

# %% [markdown]
# Zuletzt bei den Verteilungen haben wir selbst generierte Daten in Zusammenhang mit ihren Wahrscheinlichkeitsdichtefunktionien gebracht. Nun versuche ich dasselbe mit den Temperaturdaten zu denen ich die Verteilung nicht kenne. Dazu visualisiere ich erstmal die Wertebereiche für 'GCAG' und 'GISTEMP' mit Hilfe eines normierten Histogramms.

# %%
plt.figure(1, figsize=(20, 8))

plt.subplot(1,2, 1 )
plt.hist(pivot_df['GCAG'], bins=100, density=True)

plt.subplot(1,2, 2 )
plt.hist(pivot_df['GISTEMP'], bins=100, color='orange')

plt.show()

# %% [markdown]
# Und lasse mir ein paar Statistiken dazu ausgeben

# %%
pivot_df.describe()
# Out:
# Source         GCAG      GISTEMP
# count   1644.000000  1644.000000
# mean       0.048797     0.024380
# std        0.326230     0.343709
# min       -0.679600    -0.780000
# 25%       -0.190625    -0.230000
# 50%       -0.021650    -0.050000
# 75%        0.252150     0.230000
# max        1.224500     1.350000

# %% [markdown]
# Auch wenn die Daten nicht ganz normalverteilt aussehen, will ich diese Wahrscheinlichkeitsdichtefunktion über die Werte plotten. Dazu nehme ich die Mittelwert und Standardabweichung aus dem describe() Ergebnis.

# %%
loc_gcag = 0.048797
scale_gcag = 0.326230
lower = scipy.stats.norm.ppf(0.01,loc_gcag,scale_gcag)
upper = scipy.stats.norm.ppf(0.99,loc_gcag,scale_gcag)
x_gcag = scipy.linspace(lower,upper,100)

y_gcag = scipy.stats.norm.pdf(x_gcag,loc_gcag,scale_gcag)

# %%
loc_gistemp = 0.024380
scale_gistemp = 0.343709
lower = scipy.stats.norm.ppf(0.01,loc_gistemp,scale_gistemp)
upper = scipy.stats.norm.ppf(0.99,loc_gistemp,scale_gistemp)
x_gistemp = scipy.linspace(lower,upper,100)

y_gistemp = scipy.stats.norm.pdf(x_gistemp,loc_gistemp,scale_gistemp)

# %%
plt.figure(1, figsize=(20, 8))

plt.subplot(1,2, 1 )
plt.hist(pivot_df['GCAG'], bins=100, density=True)
plt.plot(x_gcag,y_gcag)

plt.subplot(1,2, 2 )
plt.hist(pivot_df['GISTEMP'], bins=100, density=True, color='orange')
plt.plot(x_gistemp,y_gistemp)

plt.show()

# %% [markdown]
# Wie unschwer zu erkennen ist, passt die Verteilung nicht genau auf die Daten und ist somit keine besonders gute Beschreibung der Daten.
#
# ** AUFGABE: ** Finde eine bessere Möglichkeit die Daten zu beschreiben

# %%
from fitter import Fitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8a80fd60fb26> in <module>()
# ----> 1 from fitter import Fitter
#
# ModuleNotFoundError: No module named 'fitter'

# %%
f = Fitter(pivot_df, distributions=['gamma', 'rayleigh', 'chi'])
f.fit()
f.summary()
# Out:
# Fitted gamma distribution with error=2.534394287162063)
# Fitted rayleigh distribution with error=6.139464788888218)
# Fitted chi distribution with error=3.6424561091151437)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
#           sumsquare_error
# gamma            2.534394
# chi              3.642456
# rayleigh         6.139465

# %% [markdown]
# ---

# %%
f = Fitter(pivot_df, distributions=None)
f.fit()
f.summary()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:312: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0/np.pi/np.sqrt(x*(1-x))
# Fitted alpha distribution with error=2.22390694051118)
# Fitted anglit distribution with error=14.50713240587018)
# Fitted arcsine distribution with error=42.91215203477515)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:6532: RuntimeWarning: divide by zero encountered in double_scalars
#   return chi**3 / (_norm_pdf_C * _argus_phi(chi)) * x * np.sqrt(y) * np.exp(-chi**2 * y / 2)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1615: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:437: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# Fitted argus distribution with error=32.31592262848028)
# Fitted beta distribution with error=2.5569486264080887)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:589: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:593: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1037: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# Fitted betaprime distribution with error=1.9736043596066026)
# Fitted bradford distribution with error=21.526781721368298)
# Fitted burr distribution with error=1.9171849105574017)
# Fitted burr12 distribution with error=3.2090930771142734)
# Fitted cauchy distribution with error=4.904790058748433)
# Fitted chi distribution with error=3.6424561091151437)
# Fitted chi2 distribution with error=2.534382115574568)
# Fitted cosine distribution with error=10.499408469842443)
# Fitted crystalball distribution with error=5.830316393434657)
# Fitted dgamma distribution with error=6.083451524260705)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1615: RuntimeWarning: divide by zero encountered in log
#   return log(self._pdf(x, *args))
# Fitted dweibull distribution with error=5.719193775803581)
# Fitted erlang distribution with error=2.534395339242226)
# Fitted expon distribution with error=27.97735350650075)
# Fitted exponnorm distribution with error=1.6795469686137436)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.4.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.266666666666666.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.066666666666666.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.644444444444444.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.807407407407405.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.951851851851851.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.367901234567901.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.187037037037037.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.217283950617285.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.202880658436214.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.093072702331963.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.163545953360767.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.02700045724737.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.169713077274807.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.084849870446579.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.045501828989487.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.966827973378042.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.143867487171672.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.982765161137362.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.8892912030686375.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.140988345837076.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 8.105741259377808.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.971703373469495.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.885621316618405.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.955289992209863.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.987679961769041.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.855691071539459.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.7306659776202835.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.810601047435183.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.6876336372476.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.514230401399217.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.2854939153640785.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.682697980388857.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.680230151959485.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.474461858837056.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.38359418279647.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.210058285384562.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.579219850885973.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.582777607981649.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.347696447387204.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.180195680886378.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.290896046064784.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.509807217502432.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.248178714238097.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.3535274032886875.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.338494013534795.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.549153071378191.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.32342230352312.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.163267958794314.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.202426403180949.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.129791381077823.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.146036613483584.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.294703394671906.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.196126817763712.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.024565876084035.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.867601807358653.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.136042784535546.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.143538156246574.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.050893472577327.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.978276799984133.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.943571933424341.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.1377127857417975.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.998576600022199.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.92609582191001.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.100222696143515.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.043480081098904.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.924253983390491.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.084348085153971.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.033376371606055.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.046514197334509.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.042812507241546.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.974254117911531.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.97008410293728.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.02463040616548.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.072226684436595.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.998747259542798.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.968121979819144.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.026916142955668.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.034952605753764.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.00767060145509.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.040730840841361.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0255813173359325.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.024868133958093.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.02193024121403.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.019437290343211.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.995581810243447.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.029443583191883.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.014494816615909.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.036241825892792.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.014813407564516.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0296300046977125.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.01827861363636.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.00723792508472.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.023892168665093.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.016059218696616.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.020462485584677.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.02694210435957.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.023909930160806.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.027231109304022.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.020516737553276.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0193672668674125.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.022760943215673.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.018583514074945.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.020778310977919.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.024120480422968.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.022736238835963.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.019926581695765.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.022052352835695.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.022758575172038.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021273377026448.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.023524574912129.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021268696892989.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.020326712334125.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.020929093959585.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0202617590836525.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021604704397685.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021261619807056.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021827586772235.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021872372234883.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021707732869055.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021330305454638.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021736855539822.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021514359934308.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021185688139176.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.02166711211397.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021600749763545.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021535957391617.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.022024586470616.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021457669287395.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021486542698586.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021621969760124.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021340208752936.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0216376938431.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021608931202129.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021590687749502.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.0215020641598755.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021591993360062.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021755914014381.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 7.021532230469141.
#   RuntimeWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(7.02159199).
#   RuntimeWarning)
# Fitted exponpow distribution with error=7.623644262927129)
# Fitted exponweib distribution with error=2.1551327570420984)
# Fitted f distribution with error=2.20126783968507)
# Fitted fatiguelife distribution with error=2.2790186607015)
# Fitted fisk distribution with error=2.1125137220675994)
# Fitted foldcauchy distribution with error=4.454561963867165)
# Fitted foldnorm distribution with error=5.862566799128106)
# Fitted frechet_l distribution with error=2.19597782298751)
# Fitted frechet_r distribution with error=4.487514620473605)
# Fitted gamma distribution with error=2.534394287162063)
# Fitted gausshyper distribution with error=5.559900929437193)
# Fitted genexpon distribution with error=6.748601458099426)
# Fitted genextreme distribution with error=2.1962411034500655)
# Fitted gengamma distribution with error=2.437176636353377)
# Fitted genhalflogistic distribution with error=21.983402442239964)
# Fitted genlogistic distribution with error=1.991654644661125)
# Fitted gennorm distribution with error=6.218158139567887)
# Fitted genpareto distribution with error=19.277471688453655)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:2159: RuntimeWarning: divide by zero encountered in true_divide
#   val = val + cnk * (-1) ** ki / (1.0 - c * ki)
# Fitted gilbrat distribution with error=18.256689711191736)
# Fitted gompertz distribution with error=9.258848625219429)
# Fitted gumbel_l distribution with error=11.581209108101389)
# Fitted gumbel_r distribution with error=1.922452543039631)
# Fitted halfcauchy distribution with error=24.887546215701864)
# Fitted halfgennorm distribution with error=14.68836162869979)
# Fitted halflogistic distribution with error=21.150964463647362)
# Fitted halfnorm distribution with error=19.857153685289326)
# Fitted hypsecant distribution with error=4.641590806561581)
# Fitted invgamma distribution with error=2.2010589089352393)
# Fitted invgauss distribution with error=2.2708839031503287)
# Fitted invweibull distribution with error=1.922611417679704)
# Fitted johnsonsb distribution with error=2.42674063732586)
# Fitted johnsonsu distribution with error=2.112028072977424)
# Fitted kappa3 distribution with error=14.756697632846564)
# Fitted kappa4 distribution with error=23.407424331868633)
# /anaconda3/lib/python3.6/site-packages/scipy/integrate/quadpack.py:385: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:44: RuntimeWarning: floating point number truncated to an integer
#   return 1.0 - sc.smirnov(n, x)
# Fitted ksone distribution with error=23.020340198547753)
# Fitted kstwobign distribution with error=2.1218392736869873)
# Fitted laplace distribution with error=4.998560187209747)
# Fitted levy distribution with error=24.771375920126403)
# Fitted levy_l distribution with error=32.766530583416305)
# SKIPPED levy_stable distribution (taking more than 30 seconds)
# Fitted loggamma distribution with error=5.850864559535408)
# Fitted logistic distribution with error=5.006366285190556)
# Fitted loglaplace distribution with error=3.928209185095756)
# Fitted lognorm distribution with error=2.2429964518870684)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:3785: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# Fitted lomax distribution with error=28.076485891133107)
# Fitted maxwell distribution with error=3.6171364276463844)
# /anaconda3/lib/python3.6/site-packages/scipy/integrate/quadpack.py:385: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   warnings.warn(msg, IntegrationWarning)
# /anaconda3/lib/python3.6/site-packages/scipy/integrate/quadpack.py:385: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# Fitted mielke distribution with error=2.168721227264563)
# Fitted moyal distribution with error=1.8013564746366562)
# Fitted nakagami distribution with error=3.6424525299056403)
# Fitted ncf distribution with error=29.476838667805684)
# Fitted nct distribution with error=2.1551518993009346)
# Fitted ncx2 distribution with error=31.050155950082537)
# Fitted norm distribution with error=5.830316171456087)
# Fitted norminvgauss distribution with error=2.0036585358650956)
# Fitted pareto distribution with error=36.526747441862376)
# Fitted pearson3 distribution with error=2.5345247518295735)
# Fitted powerlaw distribution with error=23.01017614222626)
# Fitted powerlognorm distribution with error=2.2752126206087158)
# Fitted powernorm distribution with error=3.1847017139936127)
# Fitted rayleigh distribution with error=6.139464788888218)
# Fitted rdist distribution with error=5.898014565279511)
# Fitted recipinvgauss distribution with error=2.2862462504857555)
# Fitted reciprocal distribution with error=92.30742971006079)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:5358: RuntimeWarning: invalid value encountered in log
#   self.d = np.log(b*1.0 / a)
# Fitted rice distribution with error=5.027454987064021)
# SKIPPED rv_continuous distribution (taking more than 30 seconds)
# SKIPPED rv_histogram distribution (taking more than 30 seconds)
# Fitted semicircular distribution with error=18.83093261374126)
# Fitted skewnorm distribution with error=1.9060732243434193)
# Fitted t distribution with error=5.8302768248043595)
# Fitted trapz distribution with error=34.10710425734157)
# Fitted triang distribution with error=6.581329689373622)
# Fitted truncexpon distribution with error=20.80314094500628)
# Fitted truncnorm distribution with error=5.830317410359938)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:5823: RuntimeWarning: divide by zero encountered in log
#   self._logdelta = np.log(self._delta)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:5823: RuntimeWarning: invalid value encountered in log
#   self._logdelta = np.log(self._delta)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:5883: RuntimeWarning: divide by zero encountered in power
#   Px = Fx**(lam-1.0) + (np.asarray(1-Fx))**(lam-1.0)
# Fitted tukeylambda distribution with error=17.055556579506067)
# Fitted uniform distribution with error=23.020340163351754)
# Fitted vonmises distribution with error=1.010170991549626e+59)
# Fitted vonmises_line distribution with error=5.836696507223435)
# Fitted wald distribution with error=14.68014345543987)
# Fitted weibull_max distribution with error=2.19597782298751)
# Fitted weibull_min distribution with error=4.487514620473605)
# Fitted wrapcauchy distribution with error=nan)
# /anaconda3/lib/python3.6/site-packages/scipy/optimize/optimize.py:563: RuntimeWarning: invalid value encountered in subtract
#   numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
#            sumsquare_error
# exponnorm         1.679547
# moyal             1.801356
# skewnorm          1.906073
# burr              1.917185
# gumbel_r          1.922453

# %%
f = Fitter(pivot_df, distributions=['betaprime', 'burr', 'exponnorm', 'genlogistic', 'gumbel_r', 'invweibel', 'moyal', 'vonmises'])
f.fit()
f.summary()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:589: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:593: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1037: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# Fitted betaprime distribution with error=1.9736043596066026)
# Fitted burr distribution with error=1.9171849105574017)
# Fitted exponnorm distribution with error=1.6795469686137436)
# Fitted genlogistic distribution with error=1.991654644661125)
# Fitted gumbel_r distribution with error=1.922452543039631)
# SKIPPED invweibel distribution (taking more than 30 seconds)
# Fitted moyal distribution with error=1.8013564746366562)
# Fitted vonmises distribution with error=1.010170991549626e+59)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
#            sumsquare_error
# exponnorm         1.679547
# moyal             1.801356
# burr              1.917185
# gumbel_r          1.922453
# betaprime         1.973604
